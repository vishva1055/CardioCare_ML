# %% [markdown]
# ML Project - Cardiovascular Disease

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cardio_train.csv", sep=";")

df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
df['cardio'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='cardio'>

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['cholesterol'].value_counts()
# Out:
# cholesterol
# 1    52385
# 2     9549
# 3     8066
# Name: count, dtype: int64

# %%
df['gluc'].value_counts()
# Out:
# gluc
# 1    59479
# 3     5331
# 2     5190
# Name: count, dtype: int64

# %%
plt.scatter(df['age'],df['id'])
plt.xlabel("Age")
plt.ylabel("Id")
plt.title("Sample Age Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample Age Scatter Plot')

# %%
age_outliers =df[df['age'] < 14000]
age_outliers
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 6219    8850  10878       1     175    59.0    120     80            1     1
# 22343  31922  10798       2     175    92.0    100     60            1     1
# 30666  43842  10859       1     159    59.0    120     80            1     1
# 55905  79749  10964       1     160    59.0    110     70            1     1
#
#        smoke  alco  active  cardio
# 6219       0     0       1       0
# 22343      0     0       1       0
# 30666      0     0       1       0
# 55905      0     0       1       0

# %%
df = df[df['age'] >= 14000]
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df["ageInYr"] = (df["age"] / 365).round(2)
df
# Out:
# C:\Users\Deep Gojariya\AppData\Local\Temp\ipykernel_17236\1250856226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ageInYr"] = (df["age"] / 365).round(2)
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# ...

# %%
plt.scatter(df['ageInYr'],df['id'])
plt.xlabel=('AgeInyr')
plt.ylabel=('id')
plt.title('Age In Years')
# Out:
# Text(0.5, 1.0, 'Age In Years')

# %%
df.ageInYr.value_counts()
# Out:
# ageInYr
# 59.98    100
# 56.02     95
# 55.87     93
# 53.85     93
# 56.01     93
#         ...
# 40.90      1
# 64.89      1
# 48.89      1
# 60.94      1
# 58.94      1
# Name: count, Length: 2394, dtype: int64

# %%
df = df.drop(columns=["age"])
df
# Out:
#           id  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0          0       2     168    62.0    110     80            1     1      0
# 1          1       1     156    85.0    140     90            3     1      0
# 2          2       1     165    64.0    130     70            3     1      0
# 3          3       2     169    82.0    150    100            1     1      0
# 4          4       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  99993       2     168    76.0    120     80            1     1      1
# 69996  99995       1     158   126.0    140     90            2     2      0
# 69997  99996       2     183   105.0    180     90            3     1      0
# 69998  99998       1     163    72.0    135     80            1     2      0
# 69999  99999       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  ageInYr
# ...

# %%
df = df.drop(columns=["id"])
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(77)

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 9344        1     162    62.0    110     70            1     1      0     0
# 10562       1     165    70.0    120     80            1     1      0     0
# 11129       2     165    66.0    120     80            1     1      0     0
# 13300       1     165    65.0    120     80            1     1      0     0
# 19974       1     160    60.0    120     80            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 66800       1     165    65.0    120     80            1     1      0     0
# 67576       1     160    60.0    120     80            1     1      0     0
# 68281       1     160    60.0    120     80            1     1      0     0
# 68920       1     170    68.0    120     80            1     1      0     0
# 69228       1     165    70.0    120     80            1     1      0     0
#
#        active  cardio  ageInYr
# ...

# %%
df = df.drop(df[df.duplicated()].index)
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr
# ...

# %%
plt.scatter(df['weight'],df['ageInYr'])
plt.xlabel=('Weight')
plt.ylabel=('ageInYr')
plt.title("Sample Weight Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample Weight Scatter Plot')

# %%
weight_outliers1 = df[df['weight'] < 25] 
weight_outliers2 = df[(df['weight']>=200)]
print(weight_outliers1)
print(weight_outliers2)
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 26806       1     157    23.0    110     80            1     1      0     0
# 29488       2     177    22.0    120     80            1     1      1     1
# 33817       2     178    11.0    130     90            1     1      0     0
# 57858       2     165    10.0    180   1100            2     2      0     0
# 60188       1     162    21.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr
# 26806       1       0    63.79
# 29488       1       0    55.91
# 33817       1       1    59.13
# 57858       1       1    51.52
# 60188       1       1    59.88
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 435         1     186   200.0    130     70            1     1      0     0
# 50413       2     180   200.0    150     90            1     1      0     0
#
#        active  cardio  ageInYr
# 435         0       0    45.93
# ...

# %%
df = df[~df['weight'].isin([10, 11,200])]
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr
# ...

# %%
plt.scatter(df['height'],df['ageInYr'])
plt.xlabel=("Height")
plt.ylabel=("AgeInYr")
plt.title("Sample Height vs Age Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample Height vs Age Scatter Plot')

# %%
height_outlier=df[df['height'] >=225]
height_outlier
# Out:
#       gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 6486       1     250    86.0    140    100            3     1      0     0
#
#       active  cardio  ageInYr
# 6486       1       1    58.14

# %%
df=df.drop(df[df['height'] >=225].index)
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr
# ...

# %%
plt.scatter(df['gluc'],df['ageInYr'])
plt.xlabel=("Glucose")
plt.ylabel=("AgeInYr")
plt.title("Sample Glucose Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample Glucose Scatter Plot')

# %%
plt.scatter(df['cholesterol'],df['ageInYr'])
plt.xlabel=("Cholesterol")
plt.ylabel=("AgeInYr")
plt.title("Sample Cholesterol Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample Cholesterol Scatter Plot')

# %%
df["bmi"] = (df["weight"] / (df["height"]/100)**2).round(2)
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
plt.scatter(df['bmi'],df['ageInYr'])
plt.xlabel=("BMI")
plt.ylabel=("AgeInyr")
plt.title("Sample BMI Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Sample BMI Scatter Plot')

# %%
(df['bmi'] > 80).value_counts()
# Out:
# bmi
# False    69881
# True        33
# Name: count, dtype: int64

# %%
ap_outliears = df[df['ap_hi']<df['ap_lo']]
ap_outliears
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 228         2     183    98.0    160   1100            1     2      1     0
# 241         2     157    60.0    160   1000            2     1      0     0
# 260         1     150    83.0    140    800            1     1      0     0
# 329         1     176    63.0    160   1000            2     2      0     0
# 345         1     154    81.0    140   1000            2     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69771       1     167    81.0    160   1000            1     1      0     0
# 69872       1     152    56.0    160   1000            1     1      0     0
# 69878       2     168    95.0    160   1000            1     1      0     0
# 69885       2     166    78.0    170   1000            1     1      0     0
# 69967       2     168    63.0    140   1000            1     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
ap_lo_outliers = df[df["ap_lo"] < 0]
ap_lo_outliers
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 60106       1     167    74.0     15    -70            1     1      0     0
#
#        active  cardio  ageInYr    bmi
# 60106       1       1    61.84  26.53

# %%
df = df[df["ap_lo"] >= 0]
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
tempdf = df['ap_hi'] < df['ap_lo']

df.loc[tempdf, ['ap_hi', 'ap_lo']] = df.loc[tempdf, ['ap_lo', 'ap_hi']].values

df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
df[df['ap_hi'] < df['ap_lo']]
# Out:
# Empty DataFrame
# Columns: [gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio, ageInYr, bmi]
# Index: []

# %%
plt.scatter(df['ap_lo'],df['ageInYr'])
plt.xlabel=("Ap_lo")
plt.ylabel=("AgeInYr")
plt.title=("Sample Ap_lo Scatter Plot")

# %%
ap_lo_outliears = df[df['ap_lo'] < 0] 
len(ap_lo_outliears)
# Out:
# 7

# %%
df = df[df['ap_lo'] >= 0]
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(numeric_only = True),annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  ageInYr    bmi
# ...

# %%
df.shape
# Out:
# (69906, 13)

# %% [markdown]
# Preprocessing Complete
#
# Training Begins

# %%
df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  ageInYr    bmi
# 0       1       0    50.39  21.97
# 1       1       1    55.42  34.93
# 2       0       1    51.66  23.51
# 3       1       1    48.28  28.71
# 4       0       0    47.87  23.01

# %%
from sklearn.model_selection import train_test_split


x = df.drop(columns=['cardio'])
y = df.cardio


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 10097       1     167    70.0    100     60            1     1      0     0
# 39261       1     162    71.0    130     90            1     1      0     0
# 45428       1     165    61.0    120     80            1     1      0     0
# 24072       2     166    65.0    120     80            1     1      0     0
# 1490        2     168    94.0    120    100            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 37223       1     165    93.0    130     80            1     1      0     0
# 6268        1     165    80.0    150    100            1     1      0     0
# 54949       2     172    82.0    120     80            2     1      1     0
# 861         1     165    68.0    120     80            1     1      0     0
# 15803       1     164    70.0    100     60            1     3      0     0
#
#        active  ageInYr    bmi
# ...

# %%
print(y_train)
# Out:
# 10097    0
# 39261    1
# 45428    1
# 24072    1
# 1490     0
#         ..
# 37223    0
# 6268     1
# 54949    1
# 861      0
# 15803    0
# Name: cardio, Length: 55924, dtype: int64

# %%
print(x_test)
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 66388       1     165    78.0    110     60            1     1      0     0
# 38320       1     156    84.9    140     90            1     1      0     0
# 67887       1     159   112.0    130     90            1     3      0     0
# 59392       1     155    91.0    120     80            1     1      0     0
# 46562       1     161   113.0    130     80            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 47348       1     154    60.0    100     70            1     1      0     0
# 1273        2     185    78.0    120     90            1     1      0     0
# 20835       1     151    47.0    100     70            1     1      0     0
# 14467       2     168    68.0    150     90            1     1      0     0
# 59732       1     164    63.0    110     70            1     1      0     0
#
#        active  ageInYr    bmi
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.73491288,  0.3213558 , -0.293817  , ...,  0.49513924,
#         -0.26582442, -0.41091725],
#        [-0.73491288, -0.28972854, -0.22405781, ...,  0.49513924,
#          0.80360976, -0.0836954 ],
#        [-0.73491288,  0.07692206, -0.92164971, ..., -2.0196339 ,
#          0.13650766, -0.86231561],
#        ...,
#        [ 1.36070551,  0.93244014,  0.54329327, ...,  0.49513924,
#         -0.4344489 ,  0.02873468],
#        [-0.73491288,  0.07692206, -0.43333538, ...,  0.49513924,
#          0.13207018, -0.43105398],
#        [-0.73491288, -0.04529481, -0.293817  , ...,  0.49513924,
#          1.02104658, -0.2548576 ]], shape=(55924, 12))

# %%
x_test_scaled
# Out:
# array([[-0.73491288,  0.07692206,  0.26425651, ...,  0.49513924,
#         -1.77013225,  0.18479433],
#        [-0.73491288, -1.02302975,  0.74559492, ...,  0.49513924,
#          1.0166091 ,  1.23190426],
#        [-0.73491288, -0.65637915,  2.63606895, ..., -2.0196339 ,
#          0.70006841,  2.81095947],
#        ...,
#        [-0.73491288, -1.63411409, -1.89827836, ...,  0.49513924,
#         -1.73315319, -1.16436655],
#        [ 1.36070551,  0.44357267, -0.43333538, ...,  0.49513924,
#          0.03296632, -0.58040139],
#        [-0.73491288, -0.04529481, -0.78213133, ..., -2.0196339 ,
#          0.65569355, -0.69283147]], shape=(13982, 12))

# %%
from sklearn.linear_model import LogisticRegression


logisticRegression = LogisticRegression(max_iter=1000)
logisticRegression.fit(x_train_scaled , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_prediction = logisticRegression.predict(x_test_scaled)
y_prediction
# Out:
# array([0, 1, 1, ..., 0, 1, 0], shape=(13982,))

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(confusion_matrix(y_test , y_prediction))
# Out:
# [[5074 1861]
#  [2415 4632]]

# %%
print(classification_report(y_test , y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70      6935
#            1       0.71      0.66      0.68      7047
#
#     accuracy                           0.69     13982
#    macro avg       0.70      0.69      0.69     13982
# weighted avg       0.70      0.69      0.69     13982

# %%
logisticRegression2 = LogisticRegression(max_iter=3000)
logisticRegression2.fit(x_train_scaled , y_train)
# Out:
# LogisticRegression(max_iter=3000)

# %%
y_prediction2 = logisticRegression2.predict(x_test_scaled)
y_prediction2
# Out:
# array([0, 1, 1, ..., 0, 1, 0], shape=(13982,))

# %%
print(classification_report(y_test , y_prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70      6935
#            1       0.71      0.66      0.68      7047
#
#     accuracy                           0.69     13982
#    macro avg       0.70      0.69      0.69     13982
# weighted avg       0.70      0.69      0.69     13982

# %%
from sklearn.ensemble import RandomForestClassifier

# n_estimators=100: Create 100 decision trees
# max_depth=10: Limit tree depth to prevent overfitting
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)

rf_model.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
y_pred = rf_model.predict(x_test_scaled)
y_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0], shape=(13982,))

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      6935
#            1       0.77      0.68      0.72      7047
#
#     accuracy                           0.73     13982
#    macro avg       0.74      0.73      0.73     13982
# weighted avg       0.74      0.73      0.73     13982

# %%
# K-fold - cross validation 

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

X = df.drop("cardio", axis=1)
y = df["cardio"]



rf = RandomForestClassifier(n_estimators=100, random_state=42)
scores = cross_val_score(rf, X, y, cv=skf, scoring='accuracy')
print("Average accuracy:", scores.mean())
# Out:
# Average accuracy: 0.7126570531879549

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[5505, 1430],
#        [2287, 4760]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


print("--- Performance ---")
print(f"Accuracy: {acc}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
# Out:
# --- Performance ---
# Accuracy: 0.7341582034043771
# Precision: 0.7689822294022617
# Recall: 0.6754647367674188

# %%
import pickle

with open('cardio_model.pkl', 'wb') as f:
    pickle.dump(rf_model, f)

print("Model saved successfully as 'cardio_model.pkl'")
# Out:
# Model saved successfully as 'cardio_model.pkl'
